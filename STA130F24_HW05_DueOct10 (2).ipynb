# %% [markdown]
# # STA130 Homework 05

# %% [markdown]
# ### Marking Rubric (which may award partial credit)
#
# - [0.1 points]: All relevant ChatBot summaries [including link(s) to chat log histories if you're using ChatGPT] are reported within the notebook
# - [0.3 points]: Evaluation of written communication for "Question 2"
# - [0.3 points]: Evaluation of written communication for "Question 4"
# - [0.3 points]: Evalution of submission for "Question 8"

# %% [markdown]
# ### 2. Towards the end of the "first pre-lecture" video (above) it is stated that, "It is important to note that outcomes of tests refer to the population parameter, rather than the sample statistic! As such, the result that we get is for the population." In terms of the distinctions between the concepts of $x_i\!$'s, $\bar x$, $\mu$, and $\mu_0$, how would you describe what the sentence above means? Explain this concisely in your own words for a "non-statsitical" audience, defining the technical statistical terminology you use in your answer.<br>

# %% [markdown]
# Interpreting this sentence using the example discussed in the video, when testing whether the mean salary of data scientists is $ 113,000, the focus is on whether this figure represents the average for the entire population, not just the sample.
#
# In this context, 𝑥ᵢ represents individual salaries, while 𝑥̄ is the sample mean calculated from the sample data. The true population mean is denoted by 𝜇, and the hypothesized mean we are testing against is 𝜇₀, which is $113,000 in this example.
#
# The key takeaway is that the outcomes of hypothesis tests are aimed at making inferences about the population mean 𝜇, not just the sample mean 𝑥̄. While the sample mean helps us analyze the data, the ultimate goal is to determine if the hypothesized mean 𝜇₀ aligns with the true population mean 𝜇. Therefore, hypothesis tests prioritize conclusions about the population parameter over the sample statistic.

# %% [markdown]
# ### 4. The second "Pre-lecture" video (above) describes suggest that a smaller p-value makes the null hypothesis look more ridiculous. Explain why this is in your own words in a way that makes the most sense to you, clarifying the meaning of any technical statistical terminology you use in your answer.<br>

# %% [markdown]
# A p-value helps us understand how likely our results are if nothing unusual is going on. For example, you assume your dog didn’t knock over the trash. The p-value tells you the chances of finding the trash on the floor if your dog really is innocent.
#
# If the p-value is high, it means the mess could easily happen by chance, so your dog might be innocent. But if the p-value is low, it means the mess is unlikely to happen randomly, making it more likely your dog is guilty.
#
# This means that a smaller p-value suggests something out of the ordinary might be happening.

# %% [markdown]
# ### 8. Complete the following assignment.

# %% [markdown]
# ### Fisher's Tea Experiment

# %% [markdown]
# Unlike Fisher’s original experiment, where a personal taste preference was tested, your study involves a broader student population with an interest in whether they can identify a specific pouring order.
#
# Statements of the Null and Alternative Hypothesis
# Null Hypothesis (H₀): The proportion of students who can correctly identify the order of pouring is equal to chance (50%), which could be represented as H₀:p=0.5
# Alternative Hypothesis (H₁): The proportion of students who can correctly identify the order of pouring is greater than chance (50%), suggesting they can indeed tell the difference, which can be written as H₁:p>0.5

# %% [markdown]
# Here is a methodology code for the analysis

# %% [markdown]
# ## Methodology
#
# ### 1. **Experiment Design**
#
# The study aimed to determine whether students could correctly identify the order in which milk and tea were poured. This experiment was inspired by the original Fisher and Bristol experiment.
#
# - **Sample Size**: A total of 80 students participated in the experiment.
# - **Procedure**:
#   - Each student was presented with 8 cups of tea: 4 with milk added first and 4 with tea added first.
#   - The order of the cups was randomized to eliminate any potential bias.
#   - Students were asked to identify whether milk or tea was poured first for each cup.
#
# ### 2. **Data Collection**
#
# - The responses of the 80 students were recorded, with a focus on the number of correct identifications.
# - In this study, 49 out of 80 students correctly identified the pouring order.
#
# ### 3. **Statistical Analysis**
#
# To analyze the data, a one-sample z-test for proportions was employed:
#
# #### a. **Hypotheses**
# - **Null Hypothesis (\(H_0\))**: The proportion of students who can correctly identify the order of pouring is equal to \(0.5\) (random guessing).
# - **Alternative Hypothesis (\(H_a\)**: The proportion of students who can correctly identify the order of pouring is greater than \(0.5\).
#
# #### b. **Calculations**
# - The sample proportion (\(\hat{p}\)) was calculated as follows:
#
#   \[
#   \hat{p} = \frac{x}{n} = \frac{49}{80} = 0.6125
#   \]
#
# - The standard error for the null hypothesis proportion was calculated:
#
#   \[
#   SE = \sqrt{\frac{p_0(1 - p_0)}{n}} \quad \text{where } p_0 = 0.5
#   \]
#
# - The z-test statistic was computed using the formula:
#
#   \[
#   z = \frac{\hat{p} - p_0}{SE}
#   \]
#
# #### c. **P-value Calculation**
# - The p-value for the z-test was calculated to determine the significance of the results.
#
# ### 4. **Decision Criteria**
#
# - A significance level (\(\alpha\)) of \(0.05\) was set for the test.
# - The null hypothesis was rejected if the calculated z-value was greater than the critical value of \(1.645\) or if the p-value was less than \(0.05\).
#
# ### 5. **Interpretation of Results**
#
# The results of the statistical analysis were interpreted in the context of the original Fisher and Bristol experiment. A conclusion was drawn regarding the ability of students to discern the pouring order based on their performance relative to random guessing.

# %% [markdown]
# Here is the visualization for the quantitative analysis

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data
total_students = 80
correct_identifications = 49
incorrect_identifications = total_students - correct_identifications

# Labels and values for the bar chart
labels = ['Correct Identifications', 'Incorrect Identifications']
values = [correct_identifications, incorrect_identifications]

# Create the bar chart
plt.figure(figsize=(8, 5))
bars = plt.bar(labels, values, color=['green', 'red'])

# Adding the percentage labels on top of the bars
for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval, 
             f'{yval} ({yval/total_students:.1%})', 
             ha='center', va='bottom')

# Add titles and labels
plt.title('Proportion of Correct vs Incorrect Identifications')
plt.ylabel('Number of Students')
plt.xlabel('Identification Outcome')
plt.ylim(0, total_students)

# Show the plot
plt.show()

# %% [markdown]
# Conclusion: We reject the null hypothesis. We conclude that there is statistically significant evidence that the students were able to discern the pouring order better than chance (random guessing). This suggests that their ability to identify the pouring order is not due solely to random guessing but may involve a genuine ability to discern the method of preparation.

# %% [markdown]
# Here’s a summary of our conversation:
#
# Summary of Conversation
# Fisher's Tea Experiment:
#
# You described the original Fisher and Bristol experiment, where Dr. Bristol correctly identified the pouring order of tea and milk, prompting Fisher to test if her performance was due to random guessing.
# You conducted a similar experiment with 80 students, where 49 identified the pouring order correctly.
# Statistical Analysis:
#
# We formulated null (
# 𝐻
# 0
# H
# 0
# ​
#  ) and alternative (
# 𝐻
# 𝑎
# H
# a
# ​
#  ) hypotheses:
# 𝐻
# 0
# H
# 0
# ​
#  : Proportion of correct identifications is
# 0.5
# 0.5 (random guessing).
# 𝐻
# 𝑎
# H
# a
# ​
#  : Proportion of correct identifications is greater than
# 0.5
# 0.5.
# A one-sample z-test was conducted, resulting in:
# Z-Test Statistic: Approximately
# 2.01
# 2.01
# P-Value: Approximately
# 0.0221
# 0.0221
# Decision:
#
# Based on the results:
# The z-value exceeded the critical value of
# 1.645
# 1.645.
# The p-value was less than
# 0.05
# 0.05.
# Therefore, we rejected the null hypothesis, concluding that students demonstrated a significant ability to identify the pouring order above chance.
# Visualization:
#
# I provided a code snippet to create a bar chart visualizing the proportion of correct and incorrect identifications among the students.
# Conclusion:
#
# You confirmed the rejection of the null hypothesis and discussed the implications regarding the students' discernment abilities.
# If you need any adjustments or further details added to the summary, let me know!
#
# (Sorry the format is a bit weird, I didn't know how to adjust it...)

# %% [markdown]
# And here is the link to the conversation: https://chatgpt.com/share/670f30cd-b738-800c-9fc8-eda5705fe9b1
